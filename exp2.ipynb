# %%
from utils_exp2 import run_benchmark_vs_budget, plot_final_benchmark

budgets = [1_000, 10_000, 100_000]

results, executed_budgets = run_benchmark_vs_budget(
    simulation_budgets=budgets,
    max_epochs=100,           
    eval_freq=3,
    patience=7,
    eval_samples=5_000,
    batch_size=64,
    seeds=[1, 2, 3]
)

plot_final_benchmark(results, executed_budgets)
# Out:
# === Lancement du Benchmark sur two_moons ===
#
# ...
#  NORMALISATION : NONE
# ...
#
#   >>> BUDGET DE SIMULATION : 1000 <<<
#       -> Seed 1 en cours...
#          [Epoch   1] Nouveau meilleur C2ST (1e-7) : 0.996
#          [Epoch   3] Nouveau meilleur C2ST (1e-7) : 0.985
#          [Epoch  15] Nouveau meilleur C2ST (1e-7) : 0.985
#          [Epoch  18] Nouveau meilleur C2ST (1e-7) : 0.980
#          [Epoch  21] Nouveau meilleur C2ST (1e-7) : 0.979
#          [Epoch  24] Nouveau meilleur C2ST (1e-7) : 0.974
#          [Epoch  27] Nouveau meilleur C2ST (1e-7) : 0.969
#          [Epoch  30] Nouveau meilleur C2ST (1e-7) : 0.967
#          [Epoch  33] Nouveau meilleur C2ST (1e-7) : 0.961
#          [Epoch  36] Nouveau meilleur C2ST (1e-7) : 0.939
#          [Epoch  42] Nouveau meilleur C2ST (1e-7) : 0.935
#          [Epoch  45] Nouveau meilleur C2ST (1e-7) : 0.930
#          [Epoch  48] Nouveau meilleur C2ST (1e-7) : 0.884
#          [Epoch  63] Nouveau meilleur C2ST (1e-7) : 0.859
# ...
